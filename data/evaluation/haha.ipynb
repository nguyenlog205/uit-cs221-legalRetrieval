# %%
import pandas as pd

# %%
df = pd.read_csv('gemma_finetuned_rag_result.csv')

# %%
df
# Out:
#                                            user_input  \
# 0        Hồ sơ đề nghị bổ nhiệm gồm những giấy tờ nào
# 1         Nhà nước có chính sách gì đối với BHYT?
# 2   Người tham gia BHYT đi khám chữa bệnh tại các ...
# 3   Khoản 5, Điều 66 của Nghị định 36/2016/NĐ-CP q...
# 4   Điều kiện của cơ sở an toàn sinh học cấp I là gì?
# 5   Như thế nào là đi khám chữa bệnh BHYT đúng quy...
# 6   Quầy thuốc của tôi được cấp GPP từ năm 2016 và...
# 7   Trường hợp một người đồng thời thuộc nhiều đối...
# 8   Trình tự thực hiện thủ tục Cấp Phiếu tiếp nhận...
# 9           Hợp đồng khám bệnh,chữa bệnh BHYT là gì ?
# 10  Tôi có chứng chỉ hành nghề dược trình độ cao đ...
# 11  Tổ chức Bảo hiểm y tế thanh toán chi phí KCB B...
# 12  Đối với đối tượng Thân nhân của lực lượng công...
# 13  Thầy thuốc là trưởng, phó khoa các bệnh viện v...
# 14      Cơ quan nào có trách nhiệm quản lý Quỹ BHYT ?
# 15  Kinh phí hoạt động xét tặng TTND, TTUT được Th...
# ...
